# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt  
import warnings
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(12,9)})

# %%
trainingdata = pd.read_csv(r'cs-training.csv')
# trainingdata = df.dropna()
trainingdata = shuffle(trainingdata)
trainingdata = trainingdata.drop(trainingdata.iloc[:, 0:1],axis = 1)
trainingdata = imp_mean.fit_transform(trainingdata)
X_data_train = trainingdata[:,1:len(trainingdata)]
sc = StandardScaler()
# Out:
# 150000

# %%
# graph = sns.scatterplot(x = 'MonthlyIncome' , y='SeriousDlqin2yrs' , data=X_data_train , color="r")

# ## People with High monthly income can easily return loan

# %%
train_df = pd.read_csv("cs-training.csv")
train_df.drop(train_df[['Unnamed: 0']],axis=1,inplace=True)
target = train_df['SeriousDlqin2yrs']

# %%
sns.heatmap(train_df.corr(),cmap = "Greens")
# Out:
# <AxesSubplot:>
